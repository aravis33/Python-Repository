# %% [markdown]
# # 01 Import Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02 Import Data

# %%
# Create path
path = r'/Users/dana/Documents/Instacart Basket Analysis/'

# %%
# import data
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merged.pkl'))

# %% [markdown]
# # 03 Exercise

# %%
# create smaller subset to work with
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 20)

# %%
df.head(10)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0           1.0                 2.0                8.0
# 1  2398795.0      1.0           2.0                 3.0                7.0
# 2   473747.0      1.0           3.0                 3.0               12.0
# 3  2254736.0      1.0           4.0                 4.0                7.0
# 4   431534.0      1.0           5.0                 4.0               15.0
# 5  3367565.0      1.0           6.0                 2.0                7.0
# 6   550135.0      1.0           7.0                 1.0                9.0
# 7  3108588.0      1.0           8.0                 1.0               14.0
# 8  2295261.0      1.0           9.0                 1.0               16.0
# 9  2550362.0      1.0          10.0                 4.0                8.0
#
#    days_since_last_order new_customer  product_id  add_to_cart_order  \
# 0                    NaN         True         196                1.0
# 1                   15.0        False         196                1.0
# 2                   21.0        False         196                1.0
# 3                   29.0        False         196                1.0
# 4                   28.0        False         196                1.0
# 5                   19.0        False         196                1.0
# 6                   20.0        False         196                1.0
# 7                   14.0        False         196                2.0
# 8                    0.0        False         196                4.0
# 9                   30.0        False         196                1.0
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# 0        0.0         Soda      77.0            7.0     9.0   both
# 1        1.0         Soda      77.0            7.0     9.0   both
# 2        1.0         Soda      77.0            7.0     9.0   both
# 3        1.0         Soda      77.0            7.0     9.0   both
# 4        1.0         Soda      77.0            7.0     9.0   both
# 5        1.0         Soda      77.0            7.0     9.0   both
# 6        1.0         Soda      77.0            7.0     9.0   both
# 7        1.0         Soda      77.0            7.0     9.0   both
# 8        1.0         Soda      77.0            7.0     9.0   both
# 9        1.0         Soda      77.0            7.0     9.0   both
#
#      price_range_loc     busiest day    busiest days busiest_period_of_day  \
# 0  Mid-range product  Regularly busy  Regularly busy        Average orders
# 1  Mid-range product  Regularly busy      Least busy        Average orders
# 2  Mid-range product  Regularly busy      Least busy           Most orders
# 3  Mid-range product      Least busy      Least busy        Average orders
# 4  Mid-range product      Least busy      Least busy           Most orders
# 5  Mid-range product  Regularly busy  Regularly busy        Average orders
# 6  Mid-range product  Regularly busy     Busiest day           Most orders
# 7  Mid-range product  Regularly busy     Busiest day           Most orders
# 8  Mid-range product  Regularly busy     Busiest day           Most orders
# 9  Mid-range product      Least busy      Least busy        Average orders
#
#    busiest_days
# 0           NaN
# 1    Least busy
# 2    Least busy
# 3    Least busy
# 4    Least busy
# 5           NaN
# 6  Busiest days
# 7  Busiest days
# 8  Busiest days
# 9    Least busy

# %% [markdown]
# ### Grouping Data with pandas

# %%
# group by a given column
df.groupby('product_name')

# %% [markdown]
# ### Aggregating Data with agg()

# %%
# find the mean values for order_number in each department_id group
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4.0              18.825780
# 7.0              17.472355
# 13.0             17.993423
# 14.0             19.246334
# 16.0             19.463012
# 17.0             11.294069
# 19.0             19.305237
# 20.0             17.599636

# %%
# some aggregate functions can be done without agg
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4.0     18.825780
# 7.0     17.472355
# 13.0    17.993423
# 14.0    19.246334
# 16.0    19.463012
# 17.0    11.294069
# 19.0    19.305237
# 20.0    17.599636
# Name: order_number, dtype: float64

# %%
# performing multiple aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean  min   max
# department_id
# 4.0              18.825780  1.0  99.0
# 7.0              17.472355  1.0  99.0
# 13.0             17.993423  1.0  99.0
# 14.0             19.246334  1.0  99.0
# 16.0             19.463012  1.0  99.0
# 17.0             11.294069  1.0  98.0
# 19.0             19.305237  1.0  99.0
# 20.0             17.599636  1.0  99.0

# %% [markdown]
# ### Aggregating Data with transform()

# %%
# create a max_order column
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#      order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329.0      1.0           1.0                 2.0                8.0
# 1   2398795.0      1.0           2.0                 3.0                7.0
# 2    473747.0      1.0           3.0                 3.0               12.0
# 3   2254736.0      1.0           4.0                 4.0                7.0
# 4    431534.0      1.0           5.0                 4.0               15.0
# 5   3367565.0      1.0           6.0                 2.0                7.0
# 6    550135.0      1.0           7.0                 1.0                9.0
# 7   3108588.0      1.0           8.0                 1.0               14.0
# 8   2295261.0      1.0           9.0                 1.0               16.0
# 9   2550362.0      1.0          10.0                 4.0                8.0
# 10  2968173.0     15.0          15.0                 1.0                9.0
# 11  1870022.0     15.0          17.0                 2.0               16.0
# 12  1911383.0     15.0          18.0                 2.0               11.0
# 13  2715276.0     15.0          21.0                 1.0                9.0
# 14   487368.0     15.0          22.0                 1.0               10.0
#
#     days_since_last_order new_customer  product_id  add_to_cart_order  \
# 0                     NaN         True         196                1.0
# 1                    15.0        False         196                1.0
# 2                    21.0        False         196                1.0
# 3                    29.0        False         196                1.0
# 4                    28.0        False         196                1.0
# 5                    19.0        False         196                1.0
# 6                    20.0        False         196                1.0
# 7                    14.0        False         196                2.0
# 8                     0.0        False         196                4.0
# 9                    30.0        False         196                1.0
# 10                    7.0        False         196                2.0
# 11                    8.0        False         196                6.0
# 12                    7.0        False         196                1.0
# 13                    7.0        False         196                1.0
# 14                   14.0        False         196                1.0
#
#     reordered  ... aisle_id  department_id  prices  _merge    price_range_loc  \
# 0         0.0  ...     77.0            7.0     9.0    both  Mid-range product
# 1         1.0  ...     77.0            7.0     9.0    both  Mid-range product
# 2         1.0  ...     77.0            7.0     9.0    both  Mid-range product
# 3         1.0  ...     77.0            7.0     9.0    both  Mid-range product
# 4         1.0  ...     77.0            7.0     9.0    both  Mid-range product
# 5         1.0  ...     77.0            7.0     9.0    both  Mid-range product
# 6         1.0  ...     77.0            7.0     9.0    both  Mid-range product
# 7         1.0  ...     77.0            7.0     9.0    both  Mid-range product
# 8         1.0  ...     77.0            7.0     9.0    both  Mid-range product
# 9         1.0  ...     77.0            7.0     9.0    both  Mid-range product
# 10        0.0  ...     77.0            7.0     9.0    both  Mid-range product
# 11        1.0  ...     77.0            7.0     9.0    both  Mid-range product
# 12        1.0  ...     77.0            7.0     9.0    both  Mid-range product
# 13        1.0  ...     77.0            7.0     9.0    both  Mid-range product
# 14        1.0  ...     77.0            7.0     9.0    both  Mid-range product
#
#        busiest day    busiest days busiest_period_of_day  busiest_days  \
# 0   Regularly busy  Regularly busy        Average orders           NaN
# 1   Regularly busy      Least busy        Average orders    Least busy
# 2   Regularly busy      Least busy           Most orders    Least busy
# 3       Least busy      Least busy        Average orders    Least busy
# 4       Least busy      Least busy           Most orders    Least busy
# 5   Regularly busy  Regularly busy        Average orders           NaN
# 6   Regularly busy     Busiest day           Most orders  Busiest days
# 7   Regularly busy     Busiest day           Most orders  Busiest days
# 8   Regularly busy     Busiest day           Most orders  Busiest days
# 9       Least busy      Least busy        Average orders    Least busy
# 10  Regularly busy     Busiest day           Most orders  Busiest days
# 11  Regularly busy  Regularly busy           Most orders           NaN
# 12  Regularly busy  Regularly busy           Most orders           NaN
# 13  Regularly busy     Busiest day           Most orders  Busiest days
# 14  Regularly busy     Busiest day           Most orders  Busiest days
#
#    max_order
# 0       10.0
# 1       10.0
# 2       10.0
# 3       10.0
# 4       10.0
# 5       10.0
# 6       10.0
# 7       10.0
# 8       10.0
# 9       10.0
# 10      22.0
# 11      22.0
# 12      22.0
# 13      22.0
# 14      22.0
#
# [15 rows x 21 columns]

# %%
# turn off max rows
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)

# %% [markdown]
# ### Deriving Columns with loc()

# %%
# create a flag that assigns a loyalty label to each customer
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15891507
# Loyal customer      10294027
# New customer         6249525
# NaN                       11
# Name: loyalty_flag, dtype: int64

# %%
# check results
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
